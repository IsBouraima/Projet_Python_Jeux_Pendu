# %%
#Notons que j'ai utilisé la clé 'r' pour stocker la bonne réponse.

# %%
litterature = {'Associez les amants célèbres suivants : 1) Roméo. A) Virginie. 2) Tristan. B) Juliette. 3) Abélard. C) Iseut. 4) Paul. D) Héloïse.' : {
    'a':'1D - 2A - 3B - 4C',
    'b': '1B - 2C - 3A - 4D',
    'c': '1B - 2C - 3D - 4A',
    'd': '1B - 2D - 3A - 4C',
    'r': '1B - 2C - 3D - 4A'

}, 'Georges Simenon est né :':{
    'a': 'À Paris',  
    'b': 'À Liège',
    'c': 'À Lausanne',
    'r': 'À Liège'

},'Parmi les affirmations suivantes, laquelle est exacte ?':{
    'a': 'Marcel Pagnol a écrit Les Lettres de mon moulin',
    'b': 'Alphonse Daudet a écrit Le Petit Prince',
    'c': 'Jules Renard a écrit La Jument verte',  
    'd':'Roman Rolland a écrit Jean-Christophe',
    'r':'Roman Rolland a écrit Jean-Christophe'

},'L’auteur de La Planète des Singes est' :{
    'a':'Pierre Boulle',
    'b':'Arthur C. Clark',
    'c':'Stephen King',
    'r':'Pierre Boulle'

},'La collection du Livre de Poche date de':{
    'a':'1948',
    'b':'1953',
    'c':'1960',
    'r':'1953'

},'Lequel de ces écrivains n’est pas américain ?':{
    'a':'James Joyce',
    'b':'John Steinbeck',
    'c':'William Faulkner',
    'd':'Ernest Hemingway',
    'r':'James Joyce'

},'À quels auteurs se rattachent les héros suivants ? 1) Hercule Poirot. A) Gaston Leroux. 2) Nestor Burma. B) Léo Malet. 3) Rouletabille. C) Maurice Leblanc. 4) Arsène Lupin. D) Agatha Christie':{
    'a':'1D - 2B - 3A - 4C',
    'b':'1D - 2B - 3C - 4A',
    'c':'1A - 2D - 3C - 4B',
    'd':'1D - 2A - 3B - 4C',
    'r':'1D - 2B - 3A - 4C'

},'Par quel mouvement a été inventé le jeu littéraire dit « Cadavre exquis » ?':{
    'a':'Le symbolisme',
    'b':'L’existentialisme',
    'c':'Le surréalisme',
    'd':'L’expressionnisme',
    'r':'Le surréalisme'

},'Qui est amoureuse de Rodrigue dans Le Cid et réclame pourtant son châtiment ?':{
    'a':'Chimène',
    'b':'Léonor',
    'c':'Arias',
    'd':'Elvire',
    'r':'Chimène'

},'Qui est J. K. Rowling ?':{
    'a':'Le Premier ministre de l’Australie',
    'b':'La créatrice de Harry Potter',
    'c':'Une réalisatrice de films',
    'd':'Une athlète américaine',
    'r':'La créatrice de Harry Potter'
    
}}

# %%
ecopolitique={'En économie, la valeur ajoutée d’une entreprise se calcule ':{
    'a':'En divisant le volume de production par le nombre d’ouvriers',
    'b':'En soustrayant la valeur des consommations intermédiaires au volume de production',
    'c':'En divisant le volume de production par le temps de travail',
    'd':'En soustrayant l’impôt sur les sociétés au résultat',
    'r':'En soustrayant la valeur des consommations intermédiaires au volume de production'

},'Des quatre auteurs suivants, lequel n’appartient pas au courant libéral classique ?':{
    'a':'John M. Keynes',
    'b':'David Ricardo',
    'c':'Jean Baptiste Say',
    'd':'Adam Smith',
    'r':'John M. Keynes'

},'Quelles sont, selon Karl Marx, les caractéristiques de la théorie de la plus-value ?':{
    'a':'Le rôle de l’État doit diminuer au profit d’une société collectiviste idéale, la société communiste',
    'b':'Elle engendre l’exploitation de l’homme par l’homme',
    'c':'Les propriétaires du capital (les capitalistes) exploitent les classes ouvrières qui s’appauvrissent',
    'r':'Les propriétaires du capital (les capitalistes) exploitent les classes ouvrières qui s’appauvrissent'
    
},'Parmi les conditions de la concurrence pure et parfaite, figurent':{
    'a':'Le faible nombre d’offreurs',
    'b':'L’information parfaite des offreurs et des demandeurs',
    'c':'L’homogénéité des produits',
    'r':'L’information parfaite des offreurs et des demandeurs',
    
},'L’intervention de l’État dans l’économie peut être estimée en fonction' :{
        'a':'Du poids des entreprises publiques dans le PIB',
        'b':'Du nombre de lois votées chaque année',
        'c':'Du taux de prélèvements obligatoires',
        'r':'Du poids des entreprises publiques dans le PIB'

},'La période de l’histoire des États-Unis durant laquelle furent traqués, dénoncés et arrêtés les sympathisants du parti communiste est connue sous le nom de' :{
        'a':'Prohibition',
        'b':'Watergate',
        'c':'New Deal',
        'd':'Maccarthysme',
        'r':'Maccarthysme'

},'Quel sociologue reconnu est décédé en 2002 ?':{
    'a':'Pierre Bourdieu',
    'b':'Jacques Lacan',
    'c':'Claude Lévi-Strauss',
    'r':'Pierre Bourdieu'

},'À quel fait social le sociologue Émile Durkheim a-t-il consacré un ouvrage en 1897 ?':{
    'a':'Le suicide',
    'b':'L’exploitation ouvrière',
    'c':'L’athéisme',
    'r':'Le suicide'

},'Les filles peuvent passer officiellement le baccalauréat depuis' :{
    'a':'1884',
    'b':'1919',
    'c':'1945',
    'r':'1919'

},'Un système politique dans lequel la vie politique est dominée par deux grands courants politiques correspond à la définition' :{
    'a':'D’un système bicéphale',
    'b':'D’une bipolarisation de la vie politique',
    'c':'Du bicamérisme',
    'd':'Du bipartisme',
    'e':'L’entente électorale',
    'r':'D’une bipolarisation de la vie politique'
}}

# %%
calcul={'Quel nom donne-t-on au deuxième élément (nombre) d’une division ?':{
    'a':'Le dividende',
    'b':'Le deuxième terme',
    'c':'Le quotient',
    'd':'Le diviseur',
    'r':'Le diviseur'

},'Le produit est le résultat' :{
    'a':'D’une addition',
    'b':'D’une soustraction',
    'c':'D’une multiplication',
    'd':'D’une division',
    'r':'D’une multiplication'

},'Dans un triangle rectangle, le carré de l’hypoténuse est égal' :{
    'a':'Au produit des côtés de l’angle droit',
    'b':'À la somme des carrés de l’angle droit',
    'c':'Au produit des côtés par la hauteur',
    'r':'À la somme des carrés de l’angle droit'

},'La somme des angles d’un carré est égale à' :{
    'a':'180°',
    'b':'360°',
    'c':'400°',
    'r':'360°'

},'Monsieur Durand a placé 1 500 € à sa banque. Il touche des intérêts composés annuels (les intérêts produits s’ajoutent au capital et produisent eux-mêmes des intérêts) au taux de 4 %. Au bout de cinq ans, il retire son argent. De combien dispose-t-il ?':{
    'a':'1 825 €',
    'b':'1 900 €',
    'c':'1 915 €',
    'r':'1 825 €'

},'Trouvez la figure qui possède la plus grande surface parmi les quatre propositions suivantes':{
    'a':'Un cercle de rayon r = 1 cm avec Pi = 3,14',
    'b':'Un triangle rectangle dont le côté opposé mesure 5 cm et le côté adjacent mesure 4 cm',
    'c':'Un carré de côté A = 4,5 cm',
    'd':'Un rectangle de grand côté L = 6 cm et de petit côté l = 3 cm',
    'r':'Un carré de côté A = 4,5 cm'

},'Quelle est l’aire d’un losange, si d et D sont la grande et la petite diagonale, h la hauteur et b le petit axe ?':{   
    'a': 'A = (b x h)/2',
    'b': 'A = b x h',
    'c': 'A = (D x d)/2',
    'r': 'A = (D x d)/2'

},'Un triangle a trois angles. Un petit, un moyen qui est le double du petit et un grand qui est le triple du petit. Il s’agit donc' :{
    'a':'D’un triangle quelconque',
    'b':'D’un triangle rectangle',
    'c':'D’un triangle isocèle',
    'r':'D’un triangle rectangle'

},'À l’occasion d’une intervention chirurgicale, M. Rideau s’est vu rembourser par la Sécurité sociale 77 % du coût de cette intervention. Sa mutuelle lui a remboursé 23 % des frais restants. Quel pourcentage du coût de l’intervention est-il resté à la charge de M. Rideau ?':{
    'a':'23 %', 
    'b':'17,71 %',
    'c':'5,29 %',
    'd':'0 %',
    'r':'17,71 %'

},'Une personne achète une moto d’une valeur de 10 000 € à crédit. Elle verse un acompte de 6 000 € et s’engage à verser 12 mensualités de 350 € chacune. Quel est le pourcentage d’augmentation du prix ?':{
    'a':'1,5 %',
    'b':'2 %',
    'c':'3 %',
    'd':'4 %',
    'r':'3 %'

}}

# %%
mix={'Lequel de ces écrivains n’est pas américain ?':{
    'a':'James Joyce',
    'b':'John Steinbeck',
    'c':'William Faulkner',
    'd':'Ernest Hemingway',
    'r':'James Joyce'

},'Parmi les conditions de la concurrence pure et parfaite, figurent':{
    'a':'Le faible nombre d’offreurs',
    'b':'L’information parfaite des offreurs et des demandeurs',
    'c':'L’homogénéité des produits',
    'r':'L’information parfaite des offreurs et des demandeurs',
    
},'Une personne achète une moto d’une valeur de 10 000 € à crédit. Elle verse un acompte de 6 000 € et s’engage à verser 12 mensualités de 350 € chacune. Quel est le pourcentage d’augmentation du prix ?':{
    'a':'1,5 %',
    'b':'2 %',
    'c':'3 %',
    'd':'4 %',
    'r':'3 %'

},'Qui est amoureuse de Rodrigue dans Le Cid et réclame pourtant son châtiment ?':{
    'a':'Chimène',
    'b':'Léonor',
    'c':'Arias',
    'd':'Elvire',
    'r':'Chimène'
    
},'La période de l’histoire des États-Unis durant laquelle furent traqués, dénoncés et arrêtés les sympathisants du parti communiste est connue sous le nom de' :{
    'a':'Prohibition',
    'b':'Watergate',
    'c':'New Deal',
    'd':'Maccarthysme',
    'r':'Maccarthysme'
    
},'Un triangle a trois angles. Un petit, un moyen qui est le double du petit et un grand qui est le triple du petit. Il s’agit donc' :{
    'a':'D’un triangle queconque',
    'b':'D’un triangle rectangle',
    'c':'D’un triangle isocèle',
    'r':'D’un triangle rectangle'

},'L’auteur de La Planète des Singes est' :{
    'a':'Pierre Boulle',
    'b':'Arthur C. Clark',
    'c':'Stephen King',
    'r':'Pierre Boulle'

},'Les filles peuvent passer officiellement le baccalauréat depuis' :{
    'a':'1884',
    'b':'1919',
    'c':'1945',
    'r':'1919'
  
},'Monsieur Durand a placé 1 500 € à sa banque. Il touche des intérêts composés annuels (les intérêts produits s’ajoutent au capital et produisent eux-mêmes des intérêts) au taux de 4 %. Au bout de cinq ans, il retire son argent. De combien dispose-t-il ?':{
    'a':'1 825 €',
    'b':'1 900 €',
    'c':'1 915 €',
    'r':'1 825 €'    

},'Des quatre auteurs suivants, lequel n’appartient pas au courant libéral classique ?':{
    'a':'John M. Keynes',
    'b':'David Ricardo',
    'c':'Jean Baptiste Say',
    'd':'Adam Smith',
    'r':'John M. Keynes'
}}
